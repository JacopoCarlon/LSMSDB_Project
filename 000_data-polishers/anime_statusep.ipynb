# %% [markdown]
#     head : ['username' 'anime_id' 'my_watched_episodes' 'my_start_date'
#      'my_finish_date' 'my_score' 'my_status' 'my_rewatching'
#      'my_rewatching_ep' 'my_last_updated' 'my_tags']
#
#     user_id                     !!!!!!!!!!!!!! NOT FOR NOW
#     username                          karthiga
#     anime_id                                21
#     animename                   !!!!!!!!!!!!!! NOT FOR NOW
#     my_watched_episodes                    586
#     my_score                                 9
#     my_status                                1
#     my_rewatching                          NaN
#     my_rewatching_ep                         0
#     my_rev_time                 !!!!!!! _ set emtpy
#     my_rev_text                 !!!!!!! _ set emtpy
#
#     Name: 0, dtype: object

# %%
#   add email, password
import sys
import os
import csv
import json
import pandas as pd
import time
import random

#   src :
list_anime_revs = [ 
                'username' , 
                'anime_id',
                'my_watched_episodes' , 
                'my_status' , 
                ]

#   dst :
list_for_graph = [
        'user_id'                   #get
    ,   'anime_id'              #have
    ,   'my_watched_episodes'   #have
    ,   'my_status'             #have
]


print(f'length of target cols : {len(list_anime_revs)}')



do_merge_reviews = True
if do_merge_reviews == True:

    t0 = time.time()

    # read from source
    src = './000_unpolished_csv/animelists_cleaned.csv'
    file_base = pd.read_csv(src)
    load_time = time.time()

    extracted = file_base[list_anime_revs]
    print(f'length of extr cols : {extracted.columns.values.size} ' )
    print(f'{extracted.iloc[0]}\n\n')
    t1 = time.time()
    print(f'time to load : {t1-t0}')



    #   ADD USER_ID based on USERNAME
    usernamefile = './final_csv/userid_username_graph.csv'
    with open(usernamefile, 'rb') as namefile :
        namedf = pd.read_csv(namefile)
    extracted = pd.merge(
                    extracted
                ,   namedf
                ,   on= 'username'
                ,   how = 'left'
    )
    print(f'{extracted.iloc[0]} \n\n')
    t2 = time.time()
    print(f'time to get user_id from username : {t2-t1}')


    statusdf = extracted[list_for_graph]
    #   statusdf.replace( {'user_id':'user_id' , 'anime_id':'anime_id' , 'my_watched_episodes':'watched_episodes' , 'my_status':'my_status'} )


    # SAVE to destination

    dst = './final_csv/anime_sep_graph.csv'
    if not os.path.exists(dst):
        with open(dst, 'w'): pass 
    statusdf.to_csv(dst, index=False)



    t3 = time.time()
    print(f'time to save : {t3-t2}')
    #   print(extracted.iloc[0])
    print(f'total time : {t3-t0} seconds')

    print(f'\n\n{statusdf.iloc[0]} \n\n')

    print("DBG -> the end")



#   add email, password
import sys
import os
import csv
import json
import pandas as pd
import time
import random

#   src :
list_anime_revs = [ 
                'username' , 
                'anime_id',
                'my_watched_episodes' , 
                'my_status' , 
                ]

#   dst :
list_for_graph = [
        'user_id'                   #get
    ,   'anime_id'              #have
    ,   'my_watched_episodes'   #have
    ,   'my_status'             #have
]


print(f'length of target cols : {len(list_anime_revs)}')



do_merge_reviews = True
if do_merge_reviews == True:

    t0 = time.time()

    # read from source
    src = './000_unpolished_csv/animelists_cleaned.csv'
    file_base = pd.read_csv(src)
    load_time = time.time()

    extracted = file_base[list_anime_revs]
    print(f'length of extr cols : {extracted.columns.values.size} ' )
    print(f'{extracted.iloc[0]}\n\n')
    t1 = time.time()
    print(f'time to load : {t1-t0}')



    #   ADD USER_ID based on USERNAME
    usernamefile = './final_csv/userid_username_graph.csv'
    with open(usernamefile, 'rb') as namefile :
        namedf = pd.read_csv(namefile)
    extracted = pd.merge(
                    extracted
                ,   namedf
                ,   on= 'username'
                ,   how = 'left'
    )
    print(f'{extracted.iloc[0]} \n\n')
    t2 = time.time()
    print(f'time to get user_id from username : {t2-t1}')


    statusdf = extracted[list_for_graph]
    #   statusdf.replace( {'user_id':'user_id' , 'anime_id':'anime_id' , 'my_watched_episodes':'watched_episodes' , 'my_status':'my_status'} )


    # SAVE to destination

    dst = './final_csv/anime_sep_graph.csv'
    if not os.path.exists(dst):
        with open(dst, 'w'): pass 
    statusdf.to_csv(dst, index=False)



    t3 = time.time()
    print(f'time to save : {t3-t2}')
    #   print(extracted.iloc[0])
    print(f'total time : {t3-t0} seconds')

    print(f'\n\n{statusdf.iloc[0]} \n\n')

    print("DBG -> the end")



#   add email, password
import sys
import os
import csv
import json
import pandas as pd
import time
import random

#   src :
list_anime_revs = [ 
                'username' , 
                'anime_id',
                'my_watched_episodes' , 
                'my_status' , 
                ]

#   dst :
list_for_graph = [
        'user_id'                   #get
    ,   'anime_id'              #have
    ,   'my_watched_episodes'   #have
    ,   'my_status'             #have
]


print(f'length of target cols : {len(list_anime_revs)}')



do_merge_reviews = True
if do_merge_reviews == True:

    t0 = time.time()

    # read from source
    src = './000_unpolished_csv/animelists_cleaned.csv'
    file_base = pd.read_csv(src)
    load_time = time.time()

    extracted = file_base[list_anime_revs]
    print(f'length of extr cols : {extracted.columns.values.size} ' )
    print(f'{extracted.iloc[0]}\n\n')
    t1 = time.time()
    print(f'time to load : {t1-t0}')



    #   ADD USER_ID based on USERNAME
    usernamefile = './final_csv/userid_username_graph.csv'
    with open(usernamefile, 'rb') as namefile :
        namedf = pd.read_csv(namefile)
    extracted = pd.merge(
                    extracted
                ,   namedf
                ,   on= 'username'
                ,   how = 'left'
    )
    print(f'{extracted.iloc[0]} \n\n')
    t2 = time.time()
    print(f'time to get user_id from username : {t2-t1}')


    statusdf = extracted[list_for_graph]
    #   statusdf.replace( {'user_id':'user_id' , 'anime_id':'anime_id' , 'my_watched_episodes':'watched_episodes' , 'my_status':'my_status'} )


    # SAVE to destination

    dst = './final_csv/anime_sep_graph.csv'
    if not os.path.exists(dst):
        with open(dst, 'w'): pass 
    statusdf.to_csv(dst, index=False)



    t3 = time.time()
    print(f'time to save : {t3-t2}')
    #   print(extracted.iloc[0])
    print(f'total time : {t3-t0} seconds')

    print(f'\n\n{statusdf.iloc[0]} \n\n')

    print("DBG -> the end")






#   #   length of target cols : 4
#   #   length of extr cols : 4 
#   #   username               karthiga
#   #   anime_id                     21
#   #   my_watched_episodes         586
#   #   my_status                     1
#   #   Name: 0, dtype: object
#   #   
#   #   
#   #   time to load : 27.5025417804718
#   #   username               karthiga
#   #   anime_id                     21
#   #   my_watched_episodes         586
#   #   my_status                     1
#   #   user_id                 2255153
#   #   Name: 0, dtype: object 
#   #   
#   #   
#   #   time to get user_id from username : 2.777575731277466
#   #   time to save : 24.124703407287598
#   #   total time : 54.404820919036865 seconds
#   #   
#   #   
#   #   user_id                2255153
#   #   anime_id                    21
#   #   my_watched_episodes        586
#   #   my_status                    1
#   #   Name: 0, dtype: int64 
#   #   
#   #   
#   #   DBG -> the end
# Out:
# length of target cols : 4
# length of extr cols : 4
# username               karthiga
# anime_id                     21
# my_watched_episodes         586
# my_status                     1
# Name: 0, dtype: object
#
#
# time to load : 27.5025417804718
# username               karthiga
# anime_id                     21
# my_watched_episodes         586
# my_status                     1
# user_id                 2255153
# Name: 0, dtype: object
#
#
# time to get user_id from username : 2.777575731277466
# time to save : 24.124703407287598
# total time : 54.404820919036865 seconds
#
#
# user_id                2255153
# anime_id                    21
# my_watched_episodes        586
# my_status                    1
# Name: 0, dtype: int64
#
#
# DBG -> the end
